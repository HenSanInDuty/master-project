# %%
# !pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.10/dist-packages (0.5.4)
# Requirement already satisfied: google-ai-generativelanguage==0.6.4 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (0.6.4)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.11.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.84.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.27.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (3.20.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (2.7.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.66.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from google-generativeai) (4.12.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-ai-generativelanguage==0.6.4->google-generativeai) (1.24.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.63.1)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (2.31.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (0.1.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client->google-generativeai) (4.1.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic->google-generativeai) (2.18.4)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core->google-generativeai) (1.48.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client->google-generativeai) (3.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core->google-generativeai) (2024.6.2)

# %%
import pandas as pd
import re
import json

import google.generativeai as genai

from tqdm import tqdm
import time
import traceback

# %%
genai.configure(api_key='AIzaSyAVZj--laOiadY9F8H_vFB-LWCRw8lUmyQ')
models = genai.GenerativeModel('gemini-1.5-flash')

# %%
df = pd.read_csv('/content/sample_data/IT_Job_Posting_after_error.csv')

# %%
bk_experience = []
bk_industries= []
bk_languages = []
bk_framework = []
bk_soft_skill = []
bk_tools = []

# %%
prompt = '''trích xuất số năm kinh nghiệm, ngôn ngữ lập trình, framework (nếu có), công nghệ chính (như lập trình web hay là ai chẳng hạn), kỹ năng mềm và những công cụ sử dụng sang json với cấu trúc tương tự:
    {
    "experience": "int",
    "industries":[industries1, industries2],
    "languages":[language1, language2],
    "soft-skill":[soft-skill1, soft-skill2],
    "framework":[framework1, framework2],
    "tools":[tool1, tool2]
    }
    Trong đó:
    experience: là số năm kinh nghiệm, lấy giá trị nhỏ nhất nếu có nhiều giá trị, nếu không có giá trị nào thì trả về số 0, không cần phải ghi tiêu đề hay công nghệ. chỉ là một mảng số, không phải object
    industries: là các công nghệ như lập trình ứng dụng web, lập trình ai,...
    languages: là ngôn ngữ lập trình
    soft-skill: kỹ năng mềm như thích ứng nhanh, giải quyết vấn đề,...
    framework: là những framework lập trình như react, spring boot. Nếu không đề cập tới trong câu thì để trống bằng một chuỗi rỗng, tuyệt đối không tự sinh ra bằng cách dựa vào ngôn ngữ lập trình
    tools: những tool như AWS, git, gitlab,...
    Không có giới hạn số lượng phần tử trong mảng và chỉ sử dụng thông tin trong câu, không thêm vào
    Nếu có tiếng Anh thì dịch sang tiếng Việt
    Trả về json không có ```json ở đầu và ``` ở cuối
    Từ đó phân tích câu sau (chỉ cần đưa kết quả của json không cần giải thích):\n'''

experience = bk_experience.copy()
industries = bk_industries.copy()
languages = bk_languages.copy()
framework = bk_framework.copy()
soft_skill = bk_soft_skill.copy()
tools = bk_tools.copy()

err = []

for ds in tqdm(df['request']):
  content = prompt + ds
  try:
    response = models.generate_content(content).text.split("\n")
    # Case response will have first line is ```json and last line is ```, so it much be remove
    result = json.loads(''.join(response))
    print(result)
    experience.append(result['experience'])
    industries.append(";".join(result['industries']))
    languages.append(";".join(result['languages']))
    framework.append(";".join(result['framework']))
    soft_skill.append(";".join(result['soft-skill']))
    tools.append(";".join(result['tools']))
  except Exception as e:
    experience.append(0)
    industries.append("")
    languages.append("")
    framework.append("")
    soft_skill.append("")
    tools.append("")
    traceback.print_exc()
    err.append(ds)
  finally:
    time.sleep(5)
# Out:
#   0%|          | 0/1274 [00:00<?, ?it/s]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web', 'AI'], 'languages': ['Typescript', 'Javascript'], 'soft-skill': ['Suy luận', 'Tư duy logic', 'Đọc hiểu tài liệu kỹ thuật', 'Nghiên cứu công nghệ mới'], 'framework': ['NestJs', 'ExpressJs', 'Scikit-learn', 'Keras', 'Tensorflow', 'PyTorch'], 'tools': ['Git', 'PostgreSQL', 'MongoDB', 'Redis']}
#   0%|          | 1/1274 [00:09<3:11:30,  9.03s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng máy tính để bàn'], 'languages': [], 'soft-skill': ['Giải quyết vấn đề', 'Làm việc độc lập', 'Làm việc theo nhóm'], 'framework': [], 'tools': []}
#   0%|          | 2/1274 [00:17<3:09:47,  8.95s/it]
# {'experience': 0, 'industries': ['An ninh mạng', 'Công nghệ thông tin', 'Bảo mật thông tin'], 'languages': ['bash shell', 'python', 'power shell'], 'soft-skill': ['Làm việc nhóm', 'Chịu áp lực cao', 'Năng động', 'Nhiệt tình'], 'framework': [], 'tools': ['Active Directory', 'Mail Exchange', 'CyberArk', 'Qradar', 'Entrust OTP', 'NAC', 'security endpoint', 'Email/Web security', 'monitoring tools']}
#   0%|          | 3/1274 [00:26<3:08:08,  8.88s/it]
# {'experience': 2, 'industries': ['lập trình ứng dụng web', 'AI'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'giao tiếp tốt', 'trách nhiệm', 'làm việc nhóm', 'tinh thần học hỏi'], 'framework': [], 'tools': []}
#   0%|          | 4/1274 [00:35<3:07:48,  8.87s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web'], 'languages': ['Tiếng Anh', 'Tiếng Nhật'], 'soft-skill': ['Giao tiếp tốt', 'Tư duy tích cực', 'Làm việc dưới áp lực cao'], 'framework': [], 'tools': []}
#   0%|          | 5/1274 [00:44<3:09:22,  8.95s/it]
# {'experience': 4, 'industries': ['Lập trình ứng dụng web', 'Phát triển phần mềm'], 'languages': ['Java', 'JavaScript', 'TypeScript'], 'soft-skill': ['Giải quyết vấn đề', 'Suy nghĩ phản biện', 'Làm việc độc lập', 'Làm việc nhóm', 'Thái độ làm việc chuyên nghiệp'], 'framework': ['Spring', 'Spring Boot', 'Spring Security', 'React', 'Angular'], 'tools': ['Git', 'SVN', 'NPM', 'Babel', 'ESLint', 'Webpack']}
#   0%|          | 6/1274 [00:53<3:07:31,  8.87s/it]
# {'experience': 5, 'industries': ['lập trình ứng dụng web'], 'languages': ['tiếng Anh'], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'giao tiếp hiệu quả', 'lập luận logic', 'suy nghĩ phản biện', 'hướng đến kết quả', 'tự giác', 'quản lý dự án', 'kỹ năng phối hợp'], 'framework': [], 'tools': []}
#   1%|          | 7/1274 [01:02<3:07:09,  8.86s/it]
# {'experience': 1, 'industries': ['lập trình ứng dụng web', 'an ninh mạng'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề'], 'framework': [], 'tools': []}
#   1%|          | 8/1274 [01:10<3:05:00,  8.77s/it]
# {'experience': 3, 'industries': ['kiểm thử tự động', 'kiểm thử tích hợp', 'phát triển phần mềm', 'kiểm thử phần mềm'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'chủ động', 'trách nhiệm cao', 'giao tiếp tốt', 'làm việc độc lập', 'làm việc nhóm'], 'framework': [], 'tools': ['API', 'test giả lập', 'test DB']}
#   1%|          | 9/1274 [01:19<3:03:11,  8.69s/it]
# {'experience': 3, 'industries': ['Lập trình ứng dụng web', 'Phát triển phần mềm', 'Quản lý dự án'], 'languages': ['C#', 'VB.NET', 'JavaScript'], 'soft-skill': ['Giao tiếp', 'Làm việc nhóm', 'Giải quyết vấn đề', 'Quản lý', 'Thích ứng nhanh'], 'framework': ['Angular', 'ASP.NET', 'ASP.NET MVC', 'WPF', 'MVC', 'MVVM'], 'tools': ['SVN', 'Git', 'GitLab', 'Memcached', 'Redis', 'AWS', 'EC2', 'Elastic Search', 'S3', 'FacebookAPI', 'GoogleAPI', 'SQL Server', 'MySQL', 'Postgresql', 'Oracle', 'MongoDB']}
#   1%|          | 10/1274 [01:28<3:05:41,  8.81s/it]
# {'experience': 2, 'industries': ['Lập trình ứng dụng web', 'Lập trình AI'], 'languages': ['Java'], 'soft-skill': ['Tự học tốt', 'Tư duy tốt', 'Chịu được áp lực công việc cao', 'Giải quyết vấn đề độc lập', 'Đam mê công việc', 'Tích cực tìm hiểu các kiến thức mới'], 'framework': ['Springboot'], 'tools': ['Mysql', 'Elasticsearch', 'Redis', 'Mongodb', 'Kafka', 'Git', 'Jira']}
#   1%|          | 11/1274 [01:37<3:05:01,  8.79s/it]
# {'experience': 0, 'industries': ['lập trình ứng dụng web', 'lập trình AI'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'giao tiếp', 'trình bày', 'làm việc độc lập', 'làm việc nhóm', 'kiên nhẫn', 'sáng tạo', 'viết kỹ thuật', 'kỹ năng giao tiếp'], 'framework': [], 'tools': []}
#   1%|          | 12/1274 [01:45<3:04:05,  8.75s/it]
# {'experience': 3, 'industries': ['Tài chính ngân hàng', 'Bán lẻ', 'Sales'], 'languages': [], 'soft-skill': ['Phân tích báo cáo', 'Đọc hiểu', 'Thiết kế báo cáo', 'Làm việc độc lập', 'Làm việc dưới áp lực cao'], 'framework': [], 'tools': ['Excel']}
#   1%|          | 13/1274 [01:54<3:04:09,  8.76s/it]
# {'experience': 3, 'industries': ['lập trình ứng dụng web', 'lập trình ai'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'tích cực', 'cầu tiến', 'kiên trì', 'năng động', 'sáng tạo', 'đóng góp', 'cống hiến', 'tư duy', 'tầm nhìn', 'uy tín', 'chuyên nghiệp'], 'framework': [], 'tools': ['MES', 'PLM', 'MRP']}
#   1%|          | 14/1274 [02:03<3:06:22,  8.88s/it]
# {'experience': 3, 'industries': ['Lập trình ứng dụng web', 'Lập trình AI'], 'languages': ['SQL', 'Oracle'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Năng động', 'Sáng tạo', 'Cống hiến', 'Thay đổi', 'Tạo động lực', 'Dẫn dắt đội ngũ', 'Tư duy', 'Tầm nhìn', 'Uy tín', 'Chuyên nghiệp', 'Quản lý', 'Lãnh đạo', 'Hoạch định', 'Triển khai', 'Báo cáo', 'Trình bày', 'Thuyết trình', 'Biên soạn tài liệu', 'Huấn luyện', 'Đào tạo'], 'framework': '', 'tools': ['AWS', 'Git', 'Gitlab', 'Windows', 'Linux', 'Vmware']}
#   1%|          | 15/1274 [02:13<3:11:44,  9.14s/it]
# {'experience': 3, 'industries': ['Lập trình ứng dụng web', 'Lập trình AI'], 'languages': ['C#', 'Typescript', 'JavaScript'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Kiên trì', 'Năng động', 'Sáng tạo', 'Đóng góp', 'Cống hiến', 'Lãnh đạo', 'Quản trị', 'Tác phong chuyên nghiệp', 'Báo cáo', 'Trình bày', 'Thuyết trình', 'Biên soạn tài liệu', 'Huấn luyện', 'Đào tạo'], 'framework': ['React', 'Vue.js', 'Bootstrap'], 'tools': ['SQL', 'Microsoft SQL', 'Postgresql']}
#   1%|▏         | 16/1274 [02:23<3:16:35,  9.38s/it]
# {'experience': 3, 'industries': ['Công nghệ thông tin', 'Hệ thống thông tin quản lý', 'Tài chính kế toán'], 'languages': ['Tiếng Anh'], 'soft-skill': ['Có tâm thế làm việc tích cực', 'Có tinh thần cầu tiến', 'Kiên trì và có giải pháp vượt qua khó khăn, thách thức', 'Năng động', 'Sáng tạo', 'Có tinh thần đóng góp', 'Cống hiến', 'Có tư duy', 'Có tầm nhìn', 'Có đức độ', 'Có bản lĩnh uy tín', 'Tác phong chuyên nghiệp', 'Thích ứng nhanh', 'Giải quyết vấn đề', 'Kỹ năng báo cáo', 'Kỹ năng trình bày', 'Kỹ năng thuyết trình', 'Kỹ năng biên soạn tài liệu', 'Kỹ năng huấn luyện', 'Kỹ năng đào tạo'], 'framework': [], 'tools': ['Bravo', 'AWS', 'Git', 'Gitlab']}
#   1%|▏         | 17/1274 [02:33<3:18:19,  9.47s/it]
# {'experience': 4, 'industries': ['Lập trình ứng dụng web', 'AI', 'Phân tích dữ liệu lớn', 'ERP', 'CRM', 'CDP'], 'languages': [], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Tích cực', 'Cầu tiến', 'Kiên trì', 'Năng động', 'Sáng tạo', 'Đóng góp', 'Cống hiến', 'Thay đổi', 'Ảnh hưởng tốt', 'Duy trì động lực', 'Lãnh đạo', 'Điều phối', 'Quản lý', 'Làm việc nhóm', 'Giao tiếp tốt', 'Tác phong chuẩn mực', 'Xử lý vấn đề'], 'framework': [], 'tools': ['BigQuery', 'BigTable', 'Looker']}
#   1%|▏         | 18/1274 [02:42<3:16:55,  9.41s/it]
# {'experience': 3, 'industries': ['Lập trình ứng dụng web', 'Thiết kế UI/UX'], 'languages': ['HTML5', 'CSS3', 'JavaScript', 'jQuery Mobile'], 'soft-skill': ['Giải quyết vấn đề', 'Giao tiếp', 'Thích nghi nhanh', 'Làm việc nhóm'], 'framework': [], 'tools': ['Figma', 'Photoshop', 'Illustrator']}
#   1%|▏         | 19/1274 [02:51<3:12:41,  9.21s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web', 'Lập trình AI'], 'languages': ['SQL', 'PL/SQL'], 'soft-skill': ['Kỹ năng thu thập, phân tích thông tin, dữ liệu'], 'framework': [], 'tools': ['Microsoft Excel', 'PLSQL Developer', 'Toad', 'SQL Navigator']}
#   2%|▏         | 20/1274 [02:59<3:10:21,  9.11s/it]
# {'experience': 2, 'industries': ['Lập trình ứng dụng web', 'Lập trình AI'], 'languages': ['Ruby', 'NodeJS', 'Python', 'Java', 'React'], 'soft-skill': ['Giải quyết vấn đề'], 'framework': ['Ruby on Rails'], 'tools': ['AWS', 'Git', 'GitLab']}
#   2%|▏         | 21/1274 [03:08<3:07:05,  8.96s/it]
# {'experience': 2, 'industries': ['lập trình backend'], 'languages': ['Golang', 'Python', 'NodeJS', 'Java', 'C#'], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'tư duy logic'], 'framework': [], 'tools': ['Database (SQL, NoSQL)', 'Redis', 'Message Queue(Kafka, RabbitMQ)', 'Docker', 'Docker Compose', 'K8s']}
#   2%|▏         | 22/1274 [03:17<3:08:15,  9.02s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web'], 'languages': ['HTML', 'CSS', 'Javascript', 'JSDom'], 'soft-skill': ['Học hỏi nhanh', 'Đam mê lập trình', 'Thích tìm hiểu', 'Sáng tạo'], 'framework': ['React Native', 'ReactJS'], 'tools': ['Firebase', 'AWS', 'Database']}
#   2%|▏         | 23/1274 [03:27<3:12:48,  9.25s/it]
# {'experience': 3, 'industries': ['Lập trình ứng dụng web', 'Sản phẩm SaaS', 'Sản phẩm B2B'], 'languages': [], 'soft-skill': ['Tư duy phân tích', 'Tư duy chiến lược', 'Tư duy sáng tạo', 'Giải quyết vấn đề', 'Viết tài liệu', 'Thiết kế giao diện', 'Giao tiếp', 'Làm việc nhóm'], 'framework': [], 'tools': []}
#   2%|▏         | 24/1274 [03:36<3:10:26,  9.14s/it]
# {'experience': 1, 'industries': ['lập trình ứng dụng web', 'lập trình AI', 'giáo dục Edtech'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề'], 'framework': [], 'tools': []}
#   2%|▏         | 25/1274 [03:45<3:07:08,  8.99s/it]
# {'experience': 3, 'industries': ['giáo dục kỹ năng sống', 'kỹ năng số', 'giáo dục'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'xử lý tình huống', 'lập kế hoạch', 'tổ chức công việc', 'giao tiếp hiệu quả', 'trình bày ý tưởng', 'có tinh thần trách nhiệm cao', 'mô phạm', 'nghiêm túc', 'có phẩm chất đạo đức tốt', 'nhiệt tình', 'hòa nhã', 'yêu thương', 'tận tâm với học sinh', 'tự học', 'tự bồi dưỡng'], 'framework': [], 'tools': ['MS Office']}
#   2%|▏         | 26/1274 [03:53<3:06:22,  8.96s/it]
# {'experience': 0, 'industries': ['Khoa học dữ liệu', 'Công nghệ thông tin', 'Trí tuệ nhân tạo', 'AI'], 'languages': ['Python', 'R'], 'soft-skill': ['Làm việc độc lập', 'Làm việc nhóm', 'Học hỏi', 'Nghiên cứu'], 'framework': [], 'tools': []}
#   2%|▏         | 27/1274 [04:02<3:04:15,  8.87s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web'], 'languages': ['Java'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề'], 'framework': [], 'tools': ['GIT', 'SVN', 'AWS']}
#   2%|▏         | 28/1274 [04:11<3:06:36,  8.99s/it]
# {'experience': 1, 'industries': ['Phân tích nghiệp vụ CNTT', 'Ngân hàng'], 'languages': [], 'soft-skill': ['Thu thập tổng hợp yêu cầu', 'Tư duy, phân tích vấn đề', 'Tư vấn nghiệp vụ', 'Sử dụng tốt các ứng dụng văn phòng', 'Vẽ lưu đồ quy trình', 'Giao tiếp tốt', 'Khéo léo', 'Linh hoạt', 'Hiểu biết về quy trình phát triển phần mềm', 'Các mô hình triển khai dự án'], 'framework': ['Agile', 'waterfall'], 'tools': ['Axure', 'Balsamiq']}
#   2%|▏         | 29/1274 [04:21<3:08:40,  9.09s/it]
# {'experience': 2, 'industries': ['Lập trình web', 'Phát triển thiết bị di động', 'Lập trình API'], 'languages': ['Java', 'HTML', 'Javascript', 'CSS', 'SQL'], 'soft-skill': ['Tinh thần trách nhiệm', 'Ham học hỏi', 'Phối hợp', 'Team work', 'Sharing', 'Phát triển team'], 'framework': ['Spring Framework'], 'tools': ['RDBMS', 'MYSQL']}
#   2%|▏         | 30/1274 [04:30<3:10:55,  9.21s/it]
# {'experience': 0, 'industries': ['lập trình lưu trữ', 'xử lý dữ liệu phân tán', 'xử lý dữ liệu lớn', 'xây dựng luồng xử lý dữ liệu'], 'languages': ['Python', 'SQL'], 'soft-skill': [], 'framework': ['Hadoop', 'Spark', 'Kafka', 'Zookeeper'], 'tools': ['Elastic Search', 'Oracle', 'MongoDB']}
#   2%|▏         | 31/1274 [04:39<3:07:22,  9.04s/it]
# {'experience': 2, 'industries': ['triển khai hệ thống', 'quản trị hệ thống', 'máy chủ', 'lưu trữ', 'sao lưu', 'ảo hoá'], 'languages': [], 'soft-skill': ['phối hợp', 'làm việc nhóm', 'chủ động'], 'framework': [], 'tools': ['CCNA', 'CCNP', 'MCSA', 'MCSE', 'VCP', 'Server', 'AD', 'Exchange', 'database']}
#   3%|▎         | 32/1274 [04:48<3:05:55,  8.98s/it]
# {'experience': 2, 'industries': ['CNTT'], 'languages': [], 'soft-skill': ['làm việc độc lập', 'làm việc nhóm', 'trách nhiệm cao', 'làm việc nhóm tốt', 'nhanh nhẹn', 'giao tiếp', 'chủ động', 'ham học hỏi'], 'framework': [], 'tools': []}
#   3%|▎         | 33/1274 [04:56<3:04:11,  8.91s/it]
# {'experience': 0, 'industries': ['kinh doanh', 'bán hàng', 'telesale'], 'languages': [], 'soft-skill': ['giao tiếp', 'truyền đạt thông tin', 'năng động', 'quản lý thời gian', 'có tổ chức', 'sắp xếp', 'thuyết phục', 'chăm chỉ', 'kiên trì', 'có mục tiêu'], 'framework': [], 'tools': []}
#   3%|▎         | 34/1274 [05:05<3:03:36,  8.88s/it]
# {'experience': 1, 'industries': ['lập trình ứng dụng web'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'trung thực', 'cẩn thận', 'tỉ mỉ', 'chính xác', 'tập trung cao độ', 'tư duy logic', 'giao tiếp', 'làm việc độc lập', 'làm việc nhóm'], 'framework': [], 'tools': ['ISO 27001', 'ISO 9001', 'ITIL', 'CoBIT']}
#   3%|▎         | 35/1274 [05:14<3:05:10,  8.97s/it]
# {'experience': 3, 'industries': ['Lập trình website'], 'languages': ['PHP', 'HTML', 'CSS', 'Javascript'], 'soft-skill': ['Tự học hỏi', 'Cập nhật kiến thức', 'Chủ động trong công việc', 'Đọc hiểu tiếng Anh chuyên ngành', 'Tư duy lập trình'], 'framework': ['WordPress'], 'tools': []}
#   3%|▎         | 36/1274 [05:23<3:03:34,  8.90s/it]
# {'experience': 0, 'industries': ['Dịch vụ khách hàng', 'Thương mại điện tử', 'Phần mềm', 'CNTT', 'Bán lẻ'], 'languages': [], 'soft-skill': ['Giao tiếp', 'Phân tích', 'Xử lý thông tin', 'Xử lý tình huống', 'Quản lý công việc cá nhân', 'Chu đáo', 'Nhiệt tình', 'Kiên nhẫn'], 'framework': [], 'tools': []}
#   3%|▎         | 37/1274 [05:32<3:02:24,  8.85s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web'], 'languages': [], 'soft-skill': ['Giải quyết vấn đề', 'Quản trị theo mục tiêu', 'Điều hành quản trị công việc'], 'framework': [], 'tools': []}
#   3%|▎         | 38/1274 [05:41<3:00:58,  8.79s/it]
# {'experience': 2, 'industries': ['ERP', 'Ecommerce', 'Operation', 'Accounting', 'Y tế', 'Phân tích dữ liệu', 'Microservice', 'SaaS'], 'languages': [], 'soft-skill': ['tư duy phân tích nghiệp vụ', 'tư duy logic', 'quy trình', 'tư duy tổng hợp công việc', 'làm việc có tính kế thừa', 'hình tượng mô hình hệ thống', 'phân tích nhu cầu khách hàng', 'Giao tiếp', 'teamwork', 'làm việc độc lập'], 'framework': [], 'tools': ['Jira', 'prototype', 'mockup', 'flowchart', 'mind map']}
#   3%|▎         | 39/1274 [05:50<3:02:44,  8.88s/it]
# {'experience': 2, 'industries': ['Product Design', 'UX UI Design', 'Accounting', 'E-commerce', 'CRM', 'ERP'], 'languages': [], 'soft-skill': ['tư duy thiết kế lấy người dùng/khách hàng làm trọng tâm', 'sáng tạo', 'nhiệt tình', 'ham học hỏi', 'tìm tòi kiến thức thiết kế', 'nghiên cứu', 'tìm hiểu về trải nghiệm người dùng', 'am hiểu về các nguyên lý thiết kế', 'quy chuẩn thiết kế'], 'framework': ['Design Thinking', 'Design Sprint'], 'tools': ['Figma', 'XD', 'Photoshop', 'Illustrator', 'Draw. io']}
#   3%|▎         | 40/1274 [05:59<3:02:45,  8.89s/it]
# {'experience': 2, 'industries': ['Kỹ thuật cơ khí', 'Điện công nghiệp', 'Lắp đặt và sửa chữa', 'Thủy lực', 'Hàn', 'Xây dựng'], 'languages': [], 'soft-skill': ['Giao tiếp tốt', 'Thuyết phục', 'Làm việc nhóm', 'Chịu được áp lực công việc', 'Chủ động', 'Chăm chỉ', 'Chịu khó', 'Trung thực', 'Cẩn thận', 'Nhiệt tình', 'Năng động', 'Hòa đồng'], 'framework': [], 'tools': []}
#   3%|▎         | 41/1274 [06:07<3:01:49,  8.85s/it]
# {'experience': 0, 'industries': ['Lập trình game'], 'languages': [], 'soft-skill': ['Học hỏi', 'Áp dụng công nghệ mới'], 'framework': ['Cocos Creator', '2Dx'], 'tools': []}
#   3%|▎         | 42/1274 [06:16<3:01:11,  8.82s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web'], 'languages': [], 'soft-skill': ['Nhanh nhẹn', 'Hoạt bát', 'Thân thiện', 'Hòa đồng', 'Giao tiếp', 'Chăm sóc khách hàng'], 'framework': [], 'tools': []}
#   3%|▎         | 43/1274 [06:26<3:07:13,  9.13s/it]
# {'experience': 0, 'industries': ['ngành công nghệ thông tin', 'ngành game'], 'languages': [], 'soft-skill': ['năng động', 'sáng tạo', 'hòa đồng', 'ham học hỏi', 'chăm chỉ', 'cầu toàn', 'giao tiếp tốt'], 'framework': [], 'tools': []}
#   3%|▎         | 44/1274 [06:34<3:03:27,  8.95s/it]
# {'experience': 1, 'industries': ['Game', 'Game Mechanics', 'Game Balancing', 'Gameplay Design', 'Level Design'], 'languages': [], 'soft-skill': ['Giao tiếp', 'Trình bày', 'Tư duy', 'Sáng tạo', 'Logic', 'Yêu thích chơi game', 'Cởi mở', 'Tương tác', 'Làm việc nhóm', 'Đọc hiểu tài liệu tiếng Anh'], 'framework': [], 'tools': []}
#   4%|▎         | 45/1274 [06:43<3:02:10,  8.89s/it]
# {'experience': 2, 'industries': ['lập trình ứng dụng web', 'lập trình AI'], 'languages': [], 'soft-skill': ['chịu được áp lực công việc', 'có khả năng làm việc độc lập', 'làm việc nhóm'], 'framework': [], 'tools': ['AWS', 'git', 'gitlab', 'MS AD', 'DNS', 'DHCP', 'TMG']}
#   4%|▎         | 46/1274 [06:52<3:01:40,  8.88s/it]
# {'experience': 6, 'industries': ['Thiết kế UI/UX'], 'languages': ['HTML', 'CSS'], 'soft-skill': ['Thích đu trend', 'Có khiếu thẩm mỹ', 'Nhận diện và sắp xếp bố cục hợp lý', 'Làm việc chủ động', 'Làm việc độc lập', 'Làm việc nhóm', 'Tinh thần làm việc chuyên nghiệp', 'Có trách nhiệm', 'Thích tìm tòi học hỏi', 'Trung thực', 'Thẳng thắn'], 'framework': [], 'tools': []}
#   4%|▎         | 47/1274 [07:01<2:59:42,  8.79s/it]
# {'experience': 0, 'industries': [], 'languages': [], 'soft-skill': ['Nhanh nhẹn', 'Hoạt bát', 'Thân thiện', 'Hòa đồng', 'Kỹ năng giao tiếp', 'Kỹ năng chăm sóc khách hàng'], 'framework': [], 'tools': []}
#   4%|▍         | 48/1274 [07:09<2:58:26,  8.73s/it]
# {'experience': 2, 'industries': ['lập trình ứng dụng web'], 'languages': ['Java'], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'giao tiếp', 'làm việc nhóm'], 'framework': ['Microservices', 'Redis', 'Kafka', 'Restful', 'gRPC', 'Websocket'], 'tools': ['Docker', 'Kubernetes', 'CI/CD', 'AWS']}
#   4%|▍         | 49/1274 [07:18<2:57:33,  8.70s/it]
# {'experience': 3, 'industries': ['Kiểm thử phần mềm', 'Kiểm thử mobile'], 'languages': [], 'soft-skill': ['Chủ động trong công việc', 'Có tư duy chiến lược', 'Có kỹ năng đánh giá và ra quyết định', 'Có khả năng xây dựng tài liệu kiểm thử độc lập', 'Có khả năng phân tích và phản biện về đặc tả yêu cầu phần mềm', 'Có khả năng ước lượng nỗ lực kiểm thử', 'Có khả năng xác định được những rủi ro', 'Có khả năng hướng dẫn', 'Có khả năng review về thiết kế kiểm thử', 'Có khả năng review về kịch bản kiểm thử', 'Có khả năng xây dựng và thực hiện các query cơ bản với hệ cơ sở dữ liệu', 'Hiểu và áp dụng thành thạo các kỹ thuật thiết kế kiểm thử'], 'framework': [], 'tools': ['AWS', 'Git', 'Gitlab']}
#   4%|▍         | 50/1274 [07:27<3:01:52,  8.92s/it]
# {'experience': 3, 'industries': ['Thiết kế UI/UX', 'Thiết kế web', 'Thiết kế đồ họa'], 'languages': ['HTML5', 'CSS3', 'JavaScript'], 'soft-skill': ['Giao tiếp tiếng Anh tốt'], 'framework': [], 'tools': ['Figma', 'Photoshop', 'Illustrator']}
#   4%|▍         | 51/1274 [07:35<2:57:41,  8.72s/it]
# {'experience': 2, 'industries': ['phần mềm', 'kiểm thử', 'lập trình', 'lập trình ứng dụng web'], 'languages': ['tiếng Nhật'], 'soft-skill': ['tổ chức', 'quản lý công việc', 'tự nghiên cứu', 'xây dựng tài liệu kỹ thuật', 'quản lý tài liệu kỹ thuật', 'quản lý', 'đào tạo', 'chủ động', 'nhanh nhẹn', 'hoạt bát', 'chăm chỉ', 'cầu tiến', 'ham học hỏi'], 'framework': [], 'tools': ['AWS', 'git', 'gitlab']}
#   4%|▍         | 52/1274 [07:44<2:56:33,  8.67s/it]
# {'experience': 1, 'industries': ['CNTT'], 'languages': [], 'soft-skill': ['Giao tiếp', 'Xử lý tình huống', 'Giải quyết vấn đề', 'Làm việc nhóm', 'Làm việc độc lập', 'Phân tích', 'Tổng hợp', 'Báo cáo', 'Tự trao dồi', 'Cập nhật kiến thức chuyên môn'], 'framework': [], 'tools': []}
#   4%|▍         | 53/1274 [07:53<2:57:43,  8.73s/it]
# {'experience': 1, 'industries': ['thiết kế UX', 'Ứng dụng Mobile', 'Ứng dụng Web'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'làm việc nhóm'], 'framework': [], 'tools': ['Sketch', 'Principle', 'Behance', 'Dribbble']}
#   4%|▍         | 54/1274 [08:02<2:57:53,  8.75s/it]
# {'experience': 0, 'industries': ['IT ngành nhà hàng - khách sạn'], 'languages': [], 'soft-skill': ['phân tích', 'tổng hợp', 'xử lý thông tin', 'xử lý dữ liệu', 'linh hoạt', 'trung thực', 'nhiệt tình', 'chịu được áp lực công việc cao'], 'framework': [], 'tools': ['MISA', 'Opera', 'Smile']}
#   4%|▍         | 55/1274 [08:11<2:58:36,  8.79s/it]
# {'experience': 3, 'industries': ['Lập trình ứng dụng mobile'], 'languages': ['Flutter', 'Java', 'Swift'], 'soft-skill': ['Giao tiếp'], 'framework': [], 'tools': ['Restful API']}
#   4%|▍         | 56/1274 [08:18<2:52:43,  8.51s/it]
# {'experience': 1, 'industries': ['thanh toán điện tử', 'thương mại điện tử', 'Mobile Banking', 'Omni Chanel'], 'languages': ['tiếng Anh'], 'soft-skill': ['giao tiếp', 'thuyết trình', 'soạn thảo văn bản', 'nhanh nhẹn', 'làm việc nhóm', 'trách nhiệm', 'nghiên cứu', 'phân tích', 'giải quyết vấn đề', 'học hỏi'], 'framework': [], 'tools': ['Microsoft Office', 'Word', 'Excel', 'Powerpoint']}
#   4%|▍         | 57/1274 [08:27<2:54:25,  8.60s/it]
# {'experience': 1, 'industries': ['Lập trình AI'], 'languages': ['SQL', 'Python'], 'soft-skill': ['Làm việc nhóm', 'Làm việc độc lập', 'Nhanh nhẹn', 'Ham học hỏi', 'Chủ động', 'Thẳng thắn', 'Có tinh thần trách nhiệm cao'], 'framework': [], 'tools': []}
#   5%|▍         | 58/1274 [08:36<2:55:23,  8.65s/it]
# {'experience': 5, 'industries': ['lập trình ứng dụng web'], 'languages': ['HTML', 'CSS', 'JavaScript', 'Java', 'Python'], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề'], 'framework': ['React', 'Angular', 'Vue.js'], 'tools': []}
#   5%|▍         | 59/1274 [08:45<2:54:32,  8.62s/it]
# {'experience': 5, 'industries': ['IT industry', 'platform development solutions'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'giao tiếp bằng tiếng Anh', 'giao tiếp bằng tiếng Việt', 'kỹ năng bán hàng chiến lược', 'phân tích và đánh giá', 'làm việc độc lập', 'làm việc nhóm', 'khởi xướng và dẫn dắt dự án', 'thấu hiểu nhu cầu người dùng', 'nhiệt huyết', 'chính trực', 'chịu trách nhiệm'], 'framework': [], 'tools': []}
#   5%|▍         | 60/1274 [08:55<3:02:47,  9.03s/it]
# {'experience': 1, 'industries': ['lập trình', 'giảng dạy', '3D', 'mỹ thuật', 'mầm non', 'arduino', 'raspberry', 'điện tử', 'STEAM'], 'languages': ['PHP', 'PYTHON', 'JAVA', 'JAVASCRIPT', 'HTML', 'CSS', 'SCRATCH'], 'soft-skill': ['truyền đạt', 'giao tiếp', 'tự tin', 'yêu trẻ', 'hiểu tâm lý trẻ', 'yêu thích công việc giảng dạy', 'cẩn thận', 'nghiêm túc', 'đọc hiểu tài liệu tiếng Anh'], 'framework': [], 'tools': []}
#   5%|▍         | 61/1274 [09:04<3:02:02,  9.00s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web', 'Thiết kế UI/UX'], 'languages': ['HTML', 'CSS', 'Javascript'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Giao tiếp tiếng Anh', 'Tư duy logic', 'Tư duy phản biện', 'Làm việc nhóm'], 'framework': ['Webflow'], 'tools': ['Figma', 'Adobe Design Suite']}
#   5%|▍         | 62/1274 [09:13<3:04:15,  9.12s/it]
# {'experience': 1, 'industries': ['Phát triển thị trường B2B', 'phần mềm ERP', 'kinh doanh Product'], 'languages': [], 'soft-skill': ['tự thúc đẩy', 'tự hoạch định', 'thành thạo các kĩ năng bán hàng', 'giao tiếp', 'đàm phán', 'quản trị mối quan hệ', 'tự tin chào hàng', 'năng động', 'chủ động'], 'framework': [], 'tools': []}
#   5%|▍         | 63/1274 [09:22<3:02:51,  9.06s/it]
# {'experience': 0, 'industries': [], 'languages': [], 'soft-skill': ['Làm việc nhóm', 'Học hỏi'], 'framework': [], 'tools': ['Words', 'Excel', 'Power Point']}
#   5%|▌         | 64/1274 [09:31<3:02:26,  9.05s/it]
# {'experience': 3, 'industries': ['Lập trình ứng dụng web', 'Microservices', 'Lập trình ứng dụng phân tán', 'API Gateway', 'Lập trình ứng dụng di động'], 'languages': ['C#', 'SQL'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Giao tiếp', 'Làm việc độc lập', 'Quản lý thời gian'], 'framework': ['ASP.Net', 'DAPR', 'NgINX'], 'tools': ['Docker', 'Kafka', 'RabbitMQ', 'MS-SQL', 'Git', 'Kubernetes', 'Linux', 'Windows', 'Bash', 'Powershell']}
#   5%|▌         | 65/1274 [09:41<3:08:51,  9.37s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web'], 'languages': [], 'soft-skill': ['Sức khỏe tốt', 'Nhanh nhẹn', 'Chịu khó'], 'framework': [], 'tools': []}
#   5%|▌         | 66/1274 [09:50<3:06:52,  9.28s/it]
# {'experience': 1, 'industries': ['lắp đặt, kết nối hệ thống camera', 'phần mềm', 'công nghệ thông tin'], 'languages': [], 'soft-skill': ['linh động nơi làm việc', 'đi công tác tỉnh'], 'framework': [], 'tools': ['AutoCad', 'CCNA', 'MCSA', 'Network Plus']}
#   5%|▌         | 67/1274 [09:59<3:03:26,  9.12s/it]
# {'experience': 0, 'industries': ['test'], 'languages': [], 'soft-skill': ['Nhanh nhẹn', 'nhiệt tình', 'soạn thảo', 'trình bày', 'giao tiếp', 'quản lý', 'lập kế hoạch', 'Trung thực', 'cẩn thận', 'tỉ mỉ', 'Tư duy sáng tạo', 'nắm bắt', 'học hỏi kỹ thuật mới', 'tự học', 'tự nghiên cứu', 'làm việc tự chủ', 'làm việc theo nhóm', 'Tinh thần làm việc hăng hái', 'có trách nhiệm', 'thái độ cầu tiến', 'Chủ động', 'tư duy logic', 'mạch lạc', 'nhanh nhạy', 'ứng xử', 'giao tiếp', 'chịu được áp lực cao'], 'framework': [], 'tools': []}
#   5%|▌         | 68/1274 [10:09<3:08:57,  9.40s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web', 'Viễn thông', 'Internet', 'Điện lực', 'Truyền hình cáp'], 'languages': [], 'soft-skill': ['Giao tiếp', 'Truyền đạt thông tin'], 'framework': [], 'tools': ['Smartphone']}
#   5%|▌         | 69/1274 [10:18<3:05:14,  9.22s/it]
# {'experience': 2, 'industries': ['Công nghệ thông tin', 'Điện tử', 'CNTT', 'IT', 'chuyển đổi số', 'điện toán đám mây', 'bảo mật', 'Bất động sản'], 'languages': [], 'soft-skill': ['tư vấn giải pháp', 'trình bày', 'thuyết phục', 'lên kế hoạch', 'chiến lược', 'chiến thuật', 'quản trị dự án'], 'framework': [], 'tools': ['AWS', 'Git', 'GitLab']}
#   5%|▌         | 70/1274 [10:26<3:02:13,  9.08s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web', 'Lập trình Cloud Native', 'Microservice', 'CICD', 'DepOps', 'Containerization', 'Agile/Scrum', 'xử lý bất đồng bộ', 'xử lý đa nhiệm', 'event sourcing', 'hệ thống Message Queue', 'xử lý cache', 'job'], 'languages': ['Java'], 'soft-skill': ['Giao tiếp', 'Làm việc nhóm', 'Sẵn sàng làm việc ngoài giờ hành chính', 'Trách nhiệm', 'Ham học hỏi'], 'framework': ['Spring Boot'], 'tools': ['SQL', 'noSQL', 'Jija', 'Git', 'Kafka', 'RabbitMQ']}
#   6%|▌         | 71/1274 [10:35<2:59:50,  8.97s/it]
# {'experience': 1, 'industries': ['Lập trình phần mềm', 'Cloud Native'], 'languages': ['Java'], 'soft-skill': ['Giao tiếp', 'Làm việc nhóm', 'Học hỏi'], 'framework': ['Spring Boot'], 'tools': ['Git', 'Jija', 'Kafka', 'RabbitMQ']}
#   6%|▌         | 72/1274 [10:44<3:00:09,  8.99s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web', 'AI'], 'languages': ['Vietnamese', 'Korean', 'English'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Giao tiếp', 'Phân tích', 'Làm việc nhóm', 'Giao tiếp'], 'framework': [], 'tools': ['SAP', 'SAP PI/PO', 'SAP Cloud Platform Integration', 'JIRA', 'Confluence', 'AWS', 'Git', 'GitLab']}
#   6%|▌         | 73/1274 [10:53<2:58:19,  8.91s/it]
# {'experience': 0, 'industries': ['lập trình ứng dụng web'], 'languages': [], 'soft-skill': ['trung thực', 'nhanh nhẹn', 'nhiệt tình', 'tinh thần học hỏi cao'], 'framework': [], 'tools': []}
#   6%|▌         | 74/1274 [11:02<2:57:00,  8.85s/it]
# {'experience': 2, 'industries': ['CNTT', 'Ngân hàng-Tài chính-Chứng khoán- Bảo hiểm', 'Chính phủ', 'Doanh nghiệp lớn/ Vừa và nhỏ', 'Chuyển đổi số', 'Điện toán đám mây', 'Bảo mật', 'SI'], 'languages': ['tiếng Anh'], 'soft-skill': ['Kinh doanh', 'Tư vấn giải pháp CNTT', 'Trình bày', 'Thuyết phục', 'Lên kế hoạch', 'Chiến lược', 'Chiến thuật', 'Quản trị dự án'], 'framework': [], 'tools': []}
#   6%|▌         | 75/1274 [11:10<2:56:01,  8.81s/it]
# {'experience': 1, 'industries': ['CNTT', 'hỗ trợ người dùng', 'hệ thống System', 'Network', 'Helpdesk'], 'languages': ['Tiếng anh'], 'soft-skill': ['giao tiếp tốt', 'giao tiếp với KH nước ngoài'], 'framework': [], 'tools': []}
#   6%|▌         | 76/1274 [11:19<2:57:04,  8.87s/it]
# {'experience': 4, 'industries': ['lập trình web', 'phát triển phần mềm'], 'languages': ['.Net', 'ASP.Net', 'Java'], 'soft-skill': ['giải quyết vấn đề', 'thích ứng nhanh'], 'framework': ['AngularJs', 'ReactJs'], 'tools': ['AWS', 'Git', 'Oracle', 'MS SQL']}
#   6%|▌         | 77/1274 [11:28<2:55:40,  8.81s/it]
# {'experience': 3, 'industries': ['Phát triển phần mềm', 'Triển khai Dự án công nghệ thông tin', 'Hệ thống ERP', 'Quản lý sản xuất', 'Kế hoạch sản xuất'], 'languages': [], 'soft-skill': ['Phân tích', 'Xây dựng sơ đồ nghiệp vụ', 'Mô hình hóa', 'Khái quát hóa'], 'framework': [], 'tools': ['PostgreSQL', 'Oracle', 'SQL Server', 'MySQL']}
#   6%|▌         | 78/1274 [11:37<2:57:12,  8.89s/it]
# {'experience': 3, 'industries': ['Lập trình ứng dụng web', 'Lập trình AI'], 'languages': [], 'soft-skill': ['Giải quyết vấn đề', 'Làm việc nhóm', 'Thích nghi nhanh', 'Chịu áp lực', 'Trung thực', 'Trách nhiệm', 'Làm việc chăm chỉ'], 'framework': ['VMware', 'OpenStack'], 'tools': ['DELL', 'HPE', 'IBM', 'Windows Server', 'Linux Server', 'AWS', 'Git', 'GitLab']}
#   6%|▌         | 79/1274 [11:46<2:57:03,  8.89s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web', 'An ninh mạng'], 'languages': [], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Giao tiếp tốt', 'Làm việc nhóm', 'Chịu áp lực'], 'framework': [], 'tools': ['Cisco', 'Checkpoint', 'AWS', 'Git', 'GitLab']}
#   6%|▋         | 80/1274 [11:55<2:55:03,  8.80s/it]
# {'experience': 1, 'industries': ['Vận hành hệ thống bán hàng đa kênh', 'Tối ưu website', 'App bán hàng', 'Quảng cáo', 'Phân tích dữ liệu', 'Bán hàng trên sàn TMĐT', 'Chăm sóc khách hàng'], 'languages': [], 'soft-skill': ['Tư duy phân tích', 'Chiến lược', 'Sáng tạo', 'Linh hoạt', 'Kỹ năng phân tích dữ liệu', 'Tư duy chăm sóc khách hàng', 'Kỹ năng xây dựng mối quan hệ'], 'framework': [], 'tools': ['Photoshop', 'AI', 'Canva', 'Google Analytics', 'Facebook Ads Manager', 'TikTok Ads Manager', 'Shopee', 'Lazada', 'TikTok shop']}
#   6%|▋         | 81/1274 [12:03<2:55:28,  8.83s/it]
# {'experience': 3, 'industries': ['lập trình ứng dụng web', 'Fintech'], 'languages': [], 'soft-skill': [], 'framework': [], 'tools': []}
#   6%|▋         | 82/1274 [12:12<2:55:04,  8.81s/it]
# {'experience': 0, 'industries': ['Kiểm thử phần mềm', 'Phát triển phần mềm', 'Agile/Scrum'], 'languages': [], 'soft-skill': ['Tư duy logic', 'Phân tích yêu cầu phần mềm', 'Giao tiếp tốt', 'Cẩn thận', 'Tỉ mỉ', 'Học hỏi nhanh', 'Sáng tạo', 'Thuyết trình', 'Ham học hỏi', 'Tự học', 'Chủ động', 'Vui vẻ', 'Hòa đồng', 'Truyền cảm hứng', 'Khuấy động phong trào tập thể'], 'framework': [], 'tools': ['SQL']}
#   7%|▋         | 83/1274 [12:21<2:53:31,  8.74s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web', 'DevOps', 'SystemEngineer', 'AI'], 'languages': [], 'soft-skill': ['Giao tiếp', 'Trình bày', 'Chăm chỉ', 'Cần cù', 'Có trách nhiệm', 'Tự nghiên cứu', 'Học hỏi'], 'framework': [], 'tools': ['Linux/UNIX', 'Docker', 'Oracle', 'MySQL', 'Postgres', 'Mongo', 'MariaDB', 'Container', 'Automation', 'CI/CD']}
#   7%|▋         | 84/1274 [12:30<2:56:19,  8.89s/it]
# {'experience': 2, 'industries': ['Kiểm tra phần mềm'], 'languages': [], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Tinh thần đồng đội cao', 'Sẵn sàng học hỏi', 'Chủ động', 'Quản lý thời gian', 'Suy luận logic', 'Phân tích', 'Cẩn thận'], 'framework': [], 'tools': []}
#   7%|▋         | 85/1274 [12:39<2:57:03,  8.93s/it]
# {'experience': 7, 'industries': ['An ninh mạng', 'Lập trình ứng dụng'], 'languages': [], 'soft-skill': ['Giải quyết vấn đề', 'Lãnh đạo', 'Giao tiếp', 'Làm việc nhóm', 'Thích ứng nhanh', 'Quản lý nhiều nhiệm vụ'], 'framework': [], 'tools': ['ISO/IEC 27001', 'NIST']}
#   7%|▋         | 86/1274 [12:48<2:54:20,  8.80s/it]
# {'experience': 1, 'industries': ['lập trình lưu trữ', 'xử lý dữ liệu phân tán', 'xử lý dữ liệu lớn', 'xây dựng luồng xử lý dữ liệu', 'lập trình ứng dụng web', 'AI', 'lập trình ứng dụng di động'], 'languages': ['Java', 'R', 'Python', 'Scala'], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề'], 'framework': ['Hadoop', 'Spark', 'Kafka', 'Zookeeper'], 'tools': ['AWS', 'Databrick', 'Elastic Search']}
#   7%|▋         | 87/1274 [12:56<2:54:14,  8.81s/it]
# {'experience': 1, 'industries': ['Marketing', 'Truyền thông đa phương tiện', 'F&B'], 'languages': [], 'soft-skill': ['phân tích', 'nghiên cứu từ khóa', 'làm việc nhóm', 'làm việc độc lập'], 'framework': [], 'tools': ['tin học văn phòng', 'công cụ hỗ trợ SEO']}
#   7%|▋         | 88/1274 [13:05<2:54:27,  8.83s/it]
# {'experience': 2, 'industries': ['Công nghệ thông tin', 'Ngân hàng', 'Lập trình ứng dụng web', 'Corebanking'], 'languages': ['C#', 'Java', 'SQL', 'jbase'], 'soft-skill': ['Giải quyết vấn đề', 'Đọc hiểu tài liệu'], 'framework': ['Spring', 'Hibernate'], 'tools': ['Oracle', 'Dep-Ops', 'Automation Test', 'Integration Test', 'Git']}
#   7%|▋         | 89/1274 [13:14<2:54:57,  8.86s/it]
# {'experience': 2, 'industries': ['lập trình ứng dụng web', 'lập trình cloud-native', 'DevOps', 'quản trị hệ thống', 'giám sát hệ thống', 'viết mã cơ sở hạ tầng dưới dạng mã', 'phát triển kịch bản'], 'languages': ['Python', 'Bash Shell', 'Power Shell'], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề'], 'framework': '', 'tools': ['AWS', 'Azure', 'EKS', 'EC2', 'S3', 'Route53', 'Lambda', 'Cloudwatch', 'Máy ảo', 'AKS', 'Azure SQL', 'Ansible', 'Artifactory', 'Docker', 'GitHub', 'Jenkins', 'Kubernetes', 'Maven', 'Sonar Qube', 'JBoss', 'Tomcat', 'WebLogic', 'Azure Monitor', 'CloudWatch', 'ELK Stack', 'Prometheus', 'Zabbix', 'Grafana', 'CloudFormation', 'Terraform', 'ARM Azure']}
#   7%|▋         | 90/1274 [13:24<3:03:03,  9.28s/it]
# {'experience': 2, 'industries': ['lập trình ứng dụng web'], 'languages': ['Java'], 'soft-skill': ['chủ động', 'tự tổ chức', 'tinh thần đồng đội'], 'framework': ['Spring', 'Redit'], 'tools': ['RDBMS', 'Oracle', 'MySQL', 'Restful API', 'Microservices']}
#   7%|▋         | 91/1274 [13:33<2:59:24,  9.10s/it]
# {'experience': 2, 'industries': ['lập trình ứng dụng web', 'lập trình AI'], 'languages': ['Tiếng Nhật', 'Tiếng Anh'], 'soft-skill': ['giao tiếp tốt', 'thành thạo đọc viết', 'giao tiếp mạch lạc', 'tự tin', 'trình bày', 'tự học hỏi', 'hòa đồng', 'vui vẻ', 'năng nổ', 'chủ động'], 'framework': [], 'tools': []}
#   7%|▋         | 92/1274 [13:42<2:56:31,  8.96s/it]
# {'experience': 5, 'industries': ['SEO', 'Lập trình ứng dụng web'], 'languages': [], 'soft-skill': [], 'framework': [], 'tools': ['Google Analytic', 'Google Webmaster tool', 'iView', 'iClick', 'Ahref', 'Rank tracker', 'Screaming Frog']}
#   7%|▋         | 93/1274 [13:49<2:48:18,  8.55s/it]
# {'experience': 0, 'industries': ['Công nghệ thông tin', 'Cloud', 'Infras', 'DevOps'], 'languages': [], 'soft-skill': ['Tư duy', 'Tìm tòi', 'Học hỏi nhanh', 'Làm việc độc lập', 'Chủ động'], 'framework': [], 'tools': []}
#   7%|▋         | 94/1274 [13:58<2:48:46,  8.58s/it]
# {'experience': 0, 'industries': ['lập trình ứng dụng web'], 'languages': [], 'soft-skill': ['tư duy', 'tìm tòi', 'học hỏi nhanh', 'làm việc độc lập', 'chủ động'], 'framework': [], 'tools': []}
#   7%|▋         | 95/1274 [14:07<2:48:40,  8.58s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web', 'Lập trình AI'], 'languages': ['Java', 'Python', 'JavaScript', 'Golang'], 'soft-skill': ['Làm việc độc lập', 'Làm việc theo nhóm', 'Giải quyết vấn đề', 'Tư duy logic', 'Học hỏi', 'Tiếp thu công nghệ mới', 'Năng động', 'Sáng tạo', 'Trách nhiệm', 'Chịu áp lực'], 'framework': ['React', 'Angular', 'Spring', 'Springboot', 'ASP.NET core', 'Kafka', 'Redis', 'RabbitMQ', 'ServiceStack'], 'tools': ['AWS', 'Azure', 'Git', 'MS SQL', 'MySQL', 'Oracle', 'DB2']}
#   8%|▊         | 96/1274 [14:16<2:54:10,  8.87s/it]
# {'experience': 0, 'industries': [], 'languages': [], 'soft-skill': ['Sử dụng mạng xã hội', 'Kỹ năng tìm kiếm và tổng hợp thông tin hiệu quả', 'Sử dụng thành thạo máy tính', 'Kỹ năng tin học văn phòng', 'Khả năng đọc hiểu tiếng Anh', 'Kỹ năng viết', 'Chăm chỉ', 'Cẩn thận', 'Có trách nhiệm với công việc', 'Tác phong làm việc chuyên nghiệp'], 'framework': [], 'tools': ['Facebook', 'Twitter', 'Forums', 'Google', 'Bing', 'Yahoo']}
#   8%|▊         | 97/1274 [14:25<2:52:55,  8.82s/it]
# {'experience': 0, 'industries': ['an ninh thông tin', 'hệ thống mạng'], 'languages': [], 'soft-skill': ['giải quyết vấn đề', 'giao tiếp', 'làm việc nhóm'], 'framework': [], 'tools': ['ISO 27001']}
#   8%|▊         | 98/1274 [14:34<2:53:47,  8.87s/it]
# {'experience': 2, 'industries': ['lập trình ứng dụng web', 'lập trình AI'], 'languages': [], 'soft-skill': ['Giao tiếp', 'Kỹ năng cá nhân', 'Kỹ năng trình bày', 'Phân tích', 'Giải thích', 'Thích ứng nhanh', 'Giải quyết vấn đề'], 'framework': [], 'tools': ['SEO', 'Social media', 'Email campaigns']}
#   8%|▊         | 99/1274 [14:43<2:52:43,  8.82s/it]
# {'experience': 2, 'industries': ['CNTT', 'tổng đài', 'Siptrunk', 'nội dung số', 'SaaS'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'quản lý khách hàng', 'xây dựng mối quan hệ khách hàng', 'tư duy sáng tạo', 'truyền thông', 'tạo mối quan hệ tốt'], 'framework': [], 'tools': []}
#   8%|▊         | 100/1274 [14:51<2:52:39,  8.82s/it]
# {'experience': 1, 'industries': ['Bán các dịch vụ phần mềm'], 'languages': [], 'soft-skill': ['Giao tiếp tốt', 'Thuyết phục', 'Đàm phán', 'Tổ chức', 'Quản lý thời gian'], 'framework': [], 'tools': []}
#   8%|▊         | 101/1274 [15:00<2:50:28,  8.72s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web'], 'languages': ['JavaScript', 'C#', 'ASP.NET MVC'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề'], 'framework': ['React.js', 'Redux', 'Flux', 'Scrum', 'Agile'], 'tools': ['REST', 'SOAP', 'XML', 'SASS', 'LESS', 'jest', 'mocha', 'NPM', 'Bower', 'Grunt', 'Gulp', 'Yeoman', 'AWS', 'Git', 'GitLab', 'SharePoint', 'MS SQL Server', 'MySQL']}
#   8%|▊         | 102/1274 [15:09<2:53:41,  8.89s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web'], 'languages': [], 'soft-skill': ['Chăm chỉ', 'Cẩn thận', 'Năng động', 'Chủ động', 'Giao tiếp', 'Làm việc nhóm'], 'framework': [], 'tools': []}
#   8%|▊         | 103/1274 [15:18<2:55:17,  8.98s/it]
# {'experience': 2, 'industries': ['Lập trình nhúng', 'IoT', 'Vi điều khiển'], 'languages': ['C/C++', 'Shell', 'Java', 'Python'], 'soft-skill': ['Thành thạo các công cụ quản lý source code', 'Am hiểu về quy trình phát triển phần mềm', 'Có kiến thức về kiến trúc máy tính', 'Có khả năng đọc tài liệu tiếng Anh chuyên ngành', 'Có khả năng tiếp thu và vận dụng công nghệ mới', 'Cởi mở trong giao tiếp', 'Sẵn sàng tiếp nhận góp ý từ người khác', 'Trung thực', 'Có tinh thần trách nhiệm cao', 'Khả năng chịu áp lực công việc tốt'], 'framework': ['Qt'], 'tools': ['GIT', 'Linux Kernel', 'Drivers']}
#   8%|▊         | 104/1274 [15:28<2:56:46,  9.07s/it]
# {'experience': 2, 'industries': ['lập trình ứng dụng web', 'lập trình AI'], 'languages': ['Java', 'C/C++', 'Python'], 'soft-skill': [], 'framework': [], 'tools': []}
#   8%|▊         | 105/1274 [15:36<2:55:16,  9.00s/it]
# {'experience': 0, 'industries': [], 'languages': [], 'soft-skill': ['chăm chỉ', 'ham học hỏi', 'có trách nhiệm', 'nhiệt huyết'], 'framework': [], 'tools': []}
#   8%|▊         | 106/1274 [15:45<2:54:02,  8.94s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web'], 'languages': ['Tiếng Anh'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề'], 'framework': [], 'tools': ['Telegram']}
#   8%|▊         | 107/1274 [15:54<2:52:48,  8.88s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web', 'Vận hành và Bảo trì', 'RPA'], 'languages': ['HTML', 'CSS', 'JavaScript', 'C#'], 'soft-skill': ['Tư duy logic', 'Học hỏi', 'Trách nhiệm', 'Chủ động', 'Giao tiếp', 'Đọc tài liệu tiếng Anh'], 'framework': [], 'tools': ['UiPath', 'TagUI', 'OpenRPA', 'UI.Vision', 'aWorks']}
#   8%|▊         | 108/1274 [16:03<2:53:42,  8.94s/it]
# {'experience': 3, 'industries': ['lập trình ứng dụng web', 'lập trình ứng dụng di động', 'kiểm thử phần mềm'], 'languages': [], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'làm việc nhóm', 'chủ động', 'giao tiếp hiệu quả', 'học hỏi liên tục'], 'framework': ['Appium', 'XCTest', 'LambdaTest', 'Webdriver', 'Selenium'], 'tools': ['Postman', 'SOAPUI', 'AWS', 'Git', 'GitLab']}
#   9%|▊         | 109/1274 [16:12<2:52:31,  8.89s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web'], 'languages': [], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Phân tích', 'Làm việc độc lập'], 'framework': [], 'tools': []}
#   9%|▊         | 110/1274 [16:20<2:50:55,  8.81s/it]
# {'experience': 1, 'industries': ['Game Global', 'Quảng cáo', 'Phân tích thị trường game'], 'languages': ['Tiếng Anh'], 'soft-skill': ['Sáng tạo', 'Lên ý tưởng', 'Chủ động', 'Trách nhiệm cao', 'Chịu áp lực tốt', 'Giao tiếp tốt'], 'framework': [], 'tools': ['ASO']}
#   9%|▊         | 111/1274 [16:29<2:49:26,  8.74s/it]
# {'experience': 4, 'industries': ['lập trình web'], 'languages': ['Javascript', 'HTML', 'CSS', 'SASS', 'LESS'], 'soft-skill': ['tự học', 'giải quyết vấn đề', 'thích ứng nhanh'], 'framework': ['React.js', 'Node.js', 'Nest.js'], 'tools': ['MongoDB', 'Git']}
#   9%|▉         | 112/1274 [16:38<2:49:33,  8.76s/it]Traceback (most recent call last):
#   File "<ipython-input-7-30f5fc941bc6>", line 36, in <cell line: 31>
#     result = json.loads(''.join(response))
#   File "/usr/lib/python3.10/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.10/json/decoder.py", line 340, in decode
#     raise JSONDecodeError("Extra data", s, end)
# json.decoder.JSONDecodeError: Extra data: line 1 column 209 (char 208)
#   9%|▉         | 113/1274 [16:47<2:52:24,  8.91s/it]
# {'experience': 2, 'industries': ['Lập trình Backend'], 'languages': ['Golang', 'MySQL'], 'soft-skill': ['Giải quyết vấn đề', 'Trách nhiệm cao', 'Hỗ trợ', 'Ham học hỏi'], 'framework': [], 'tools': ['Git', 'Docker', 'Kubernetes', 'CI/CD']}
#   9%|▉         | 114/1274 [16:56<2:51:05,  8.85s/it]
# {'experience': 0, 'industries': ['công nghệ', 'ngành điều phối viên'], 'languages': [], 'soft-skill': ['giao tiếp', 'viết tiếng Anh', 'sắp xếp', 'problem-solving', 'tư duy logic'], 'framework': [], 'tools': ['Excel', 'Word', 'Jira', 'Trello']}
#   9%|▉         | 115/1274 [17:04<2:49:06,  8.75s/it]
# {'experience': 0, 'industries': ['tuyển dụng'], 'languages': [], 'soft-skill': [], 'framework': [], 'tools': []}
#   9%|▉         | 116/1274 [17:12<2:41:33,  8.37s/it]
# {'experience': 2, 'industries': ['Lập trình web'], 'languages': ['JavaScript'], 'soft-skill': ['Phân tích', 'Giải quyết vấn đề', 'Kiểm thử'], 'framework': ['NestJS', 'ReactJS', 'Angular'], 'tools': ['MongoDB']}
#   9%|▉         | 117/1274 [17:21<2:43:57,  8.50s/it]
# {'experience': 1, 'industries': ['Phát triển ứng dụng di động'], 'languages': ['Flutter', 'Dart'], 'soft-skill': ['Thiết kế UI/UX', 'Lập trình sạch', 'Debug', 'Tối ưu hóa hiệu suất', 'Làm việc độc lập', 'Làm việc nhóm', 'Giao tiếp', 'Giải quyết vấn đề'], 'framework': ['Flutter'], 'tools': []}
#   9%|▉         | 118/1274 [17:30<2:47:22,  8.69s/it]
# {'experience': 2, 'industries': ['Hệ thống Data Center', 'Network', 'Windows', 'Linux System', 'Nền tảng ảo hóa', 'Bảo mật'], 'languages': [], 'soft-skill': ['Viết quy trình', 'Viết tài liệu bảo mật'], 'framework': [], 'tools': ['CCNA', 'CCNP', 'MCSA', 'CEH', 'LPI']}
#   9%|▉         | 119/1274 [17:38<2:47:37,  8.71s/it]
# {'experience': 2, 'industries': ['hỗ trợ người dùng'], 'languages': [], 'soft-skill': ['thân thiện', 'có tinh thần hỗ trợ đồng đội', 'sẵn sàng di chuyển', 'làm việc linh hoạt'], 'framework': [], 'tools': []}
#   9%|▉         | 120/1274 [17:47<2:47:18,  8.70s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web'], 'languages': ['Javascript', 'NodeJS', 'HTML', 'CSS'], 'soft-skill': ['Tư duy lập trình', 'Tư duy logic hệ thống', 'Ham học hỏi', 'Thích nghi nhanh', 'Tự giác', 'Cẩn thận', 'Trách nhiệm'], 'framework': ['Nestjs', 'Angular', 'ExpressJS', 'React', 'Vuejs', 'React-native'], 'tools': ['MySQL', 'Postgres', 'MongoDB']}
#   9%|▉         | 121/1274 [17:56<2:48:11,  8.75s/it]
# {'experience': 1, 'industries': ['Công nghệ thông tin'], 'languages': [], 'soft-skill': ['Làm việc độc lập', 'Làm việc nhóm', 'Năng động', 'Giọng nói rõ ràng, lưu loát', 'Cẩn thận', 'Trách nhiệm', 'Làm việc theo ca kíp', 'Chăm sóc khách hàng'], 'framework': [], 'tools': ['Website', 'Mobile app', 'FB ads', 'Google adwords']}
#  10%|▉         | 122/1274 [18:05<2:50:48,  8.90s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web'], 'languages': ['HTML', 'CSS', 'SASS', 'PHP', 'Javascript'], 'soft-skill': ['Chăm chỉ', 'Có khả năng tự nghiên cứu', 'Giao tiếp tốt', 'Chăm chỉ', 'Kiên trì', 'Cẩn thận trong công việc', 'Đam mê', 'Có tinh thần cầu tiến', 'Có khả năng tự học'], 'framework': ['Laravel', 'Bootstrap', 'Angular', 'React'], 'tools': ['Git', 'Git bash', 'VSCode Git Extension', 'VSCode', 'Sublime Text']}
#  10%|▉         | 123/1274 [18:14<2:51:10,  8.92s/it]
# {'experience': 2, 'industries': ['Lập trình ứng dụng di động'], 'languages': ['React Native', 'HTML', 'CSS'], 'soft-skill': ['Giải quyết vấn đề', 'Giao tiếp', 'Làm việc nhóm', 'Phân tích'], 'framework': ['Jest', 'Detox'], 'tools': ['AWS', 'Git', 'GitLab']}
#  10%|▉         | 124/1274 [18:23<2:50:46,  8.91s/it]
# {'experience': 2, 'industries': ['Phát triển Backend', 'Ngành tài chính', 'Ngành ngân hàng'], 'languages': ['Java', 'SQL'], 'soft-skill': ['Giải quyết vấn đề', 'Giao tiếp', 'Làm việc độc lập', 'Làm việc nhóm'], 'framework': ['Spring', 'Hibernate'], 'tools': ['Automation Test', 'Integration Test']}
#  10%|▉         | 125/1274 [18:32<2:50:53,  8.92s/it]
# {'experience': 1, 'industries': ['Kiểm thử phần mềm', 'Kiểm thử UAT'], 'languages': ['SQL'], 'soft-skill': ['Phân tích kết quả kiểm thử', 'Báo cáo', 'Giao tiếp', 'Đàm phán', 'Làm việc nhóm', 'Giải quyết vấn đề'], 'framework': [], 'tools': []}
#  10%|▉         | 126/1274 [18:41<2:48:09,  8.79s/it]
# {'experience': 1, 'industries': ['Lập trình web'], 'languages': ['C#', 'JavaScript'], 'soft-skill': ['Phân tích thiết kế hệ thống', 'Tự tìm tòi và giải quyết vấn đề', 'Chủ động', 'Trách nhiệm', 'Cẩn thận', 'Tỉ mỉ'], 'framework': ['ASP.NET', 'Entity Framework'], 'tools': ['SQL Server', 'Git', 'Visual Studio']}
#  10%|▉         | 127/1274 [18:49<2:47:07,  8.74s/it]
# {'experience': 4, 'industries': ['Mobile Development', 'Lập trình ứng dụng web'], 'languages': ['JavaScript', 'Swift', 'Kotlin', 'Flutter'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Giao tiếp'], 'framework': ['React Native', 'Material-UI (MUI)', 'Flutter'], 'tools': ['Git', 'Jira', 'AWS']}
#  10%|█         | 128/1274 [18:58<2:46:45,  8.73s/it]
# {'experience': 6, 'industries': ['bán hàng', 'tư vấn', 'Sale B2B', 'Technology', 'Digital Transformantion', 'kinh doanh', 'bán hàng', 'tư vấn'], 'languages': [], 'soft-skill': ['chủ động', 'sẵn sàng', 'định hướng phát triển nghề nghiệp'], 'framework': [], 'tools': ['laptop cá nhân']}
#  10%|█         | 129/1274 [19:07<2:46:52,  8.74s/it]
# {'experience': 2, 'industries': ['công nghệ', 'viễn thông', 'tự động hóa'], 'languages': [], 'soft-skill': ['làm việc độc lập', 'làm việc nhóm'], 'framework': [], 'tools': ['máy tính văn phòng']}
#  10%|█         | 130/1274 [19:15<2:43:27,  8.57s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web'], 'languages': [], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề'], 'framework': [], 'tools': ['CCNA']}
#  10%|█         | 131/1274 [19:24<2:44:46,  8.65s/it]
# ...
#  97%|█████████▋| 1230/1274 [3:03:29<06:39,  9.08s/it]
# {'experience': 0, 'industries': ['Kiểm thử phần mềm'], 'languages': [], 'soft-skill': ['Siêng năng', 'chịu khó học hỏi', 'cẩn thận', 'nắm bắt nhanh', 'tỉ mỉ', 'chi tiết', 'viết tài liệu', 'giao tiếp', 'làm việc độc lập', 'làm việc nhóm'], 'framework': [], 'tools': []}
#  97%|█████████▋| 1231/1274 [3:03:38<06:29,  9.07s/it]
# {'experience': 0, 'industries': ['lập trình ứng dụng web'], 'languages': ['PHP', 'Reactjs'], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'làm việc nhóm', 'làm việc độc lập', 'chịu áp lực', 'chủ động', 'ham học hỏi'], 'framework': ['Lavarel', 'Reactjs', 'Wordpress'], 'tools': ['Laptop']}
#  97%|█████████▋| 1232/1274 [3:03:47<06:21,  9.07s/it]
# {'experience': 1, 'industries': ['IT'], 'languages': [], 'soft-skill': ['Giao tiếp mạch lạc', 'Kỹ năng bán hàng', 'Kỹ năng giải quyết vấn đề', 'Kỹ năng trình bày'], 'framework': [], 'tools': []}
#  97%|█████████▋| 1233/1274 [3:03:56<06:11,  9.06s/it]
# {'experience': 1, 'industries': ['lập trình ứng dụng web'], 'languages': ['PHP'], 'soft-skill': [], 'framework': ['Laravel'], 'tools': ['MySQL', 'Git']}
#  97%|█████████▋| 1234/1274 [3:04:04<05:45,  8.64s/it]
# {'experience': 2, 'industries': ['lập trình ứng dụng web', 'kiểm thử tự động', 'kiểm thử ứng dụng di động'], 'languages': ['Java'], 'soft-skill': [], 'framework': ['serenity', 'appium', 'junit'], 'tools': []}
#  97%|█████████▋| 1235/1274 [3:04:13<05:46,  8.88s/it]
# {'experience': 2, 'industries': ['Lập trình ứng dụng web'], 'languages': ['Java'], 'soft-skill': ['Chịu áp lực cao', 'Tuân thủ kỷ luật', 'Làm việc nhóm', 'Làm việc độc lập'], 'framework': ['Struts', 'Spring'], 'tools': ['Oracle', 'Web service', 'SOAP']}
#  97%|█████████▋| 1236/1274 [3:04:23<05:45,  9.10s/it]
# {'experience': 1, 'industries': ['IT'], 'languages': [], 'soft-skill': ['Giao tiếp mạch lạc', 'Kỹ năng bán hàng', 'Kỹ năng giải quyết vấn đề', 'Kỹ năng trình bày tốt', 'Thích ứng nhanh'], 'framework': [], 'tools': []}
#  97%|█████████▋| 1237/1274 [3:04:32<05:34,  9.04s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web', 'Giáo dục trực tuyến'], 'languages': [], 'soft-skill': ['Giải quyết vấn đề'], 'framework': [], 'tools': ['Moodle', 'Canvas', 'LMS', 'CSDL', 'Laptop']}
#  97%|█████████▋| 1238/1274 [3:04:41<05:23,  8.98s/it]
# {'experience': 2, 'industries': ['IT', 'Gia công phần mềm'], 'languages': [], 'soft-skill': ['Giao tiếp mạch lạc', 'Bán hàng', 'Giải quyết vấn đề', 'Trình bày'], 'framework': [], 'tools': []}
#  97%|█████████▋| 1239/1274 [3:04:50<05:11,  8.91s/it]
# {'experience': 0, 'industries': ['lập trình web'], 'languages': ['tiếng Nhật', 'tiếng Anh'], 'soft-skill': ['tư duy logic', 'giao tiếp', 'dịch viết'], 'framework': [], 'tools': ['MS Words', 'Excel', 'Power Point']}
#  97%|█████████▋| 1240/1274 [3:04:59<05:03,  8.91s/it]
# {'experience': 0, 'industries': [], 'languages': [], 'soft-skill': ['Cầu tiến', 'ham học hỏi', 'trung thực', 'chủ động', 'có tinh thần trách nhiệm'], 'framework': [], 'tools': ['tin học văn phòng']}
#  97%|█████████▋| 1241/1274 [3:05:08<04:59,  9.07s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web', 'AI'], 'languages': [], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Làm việc nhóm', 'Chịu được áp lực công việc'], 'framework': [], 'tools': ['MES', 'Thiết bị mạng', 'Database']}
#  97%|█████████▋| 1242/1274 [3:05:17<04:50,  9.08s/it]
# {'experience': 5, 'industries': ['lập trình ứng dụng web', 'lập trình AI'], 'languages': [], 'soft-skill': ['lãnh đạo', 'tổ chức', 'chú ý đến chi tiết', 'đa nhiệm', 'làm việc trong môi trường nhanh, định hướng nhóm', 'làm việc dưới áp lực cao', 'sẵn sàng học hỏi', 'chịu thử thách', 'hỗ trợ kinh doanh'], 'framework': [], 'tools': ['Server', 'Database', 'Network']}
#  98%|█████████▊| 1243/1274 [3:05:26<04:41,  9.08s/it]
# {'experience': 4, 'industries': ['Lập trình ứng dụng web', 'Kiểm thử phần mềm'], 'languages': [], 'soft-skill': ['Thông minh', 'Nhanh nhẹn', 'Chịu được môi trường làm việc áp lực cao', 'Năng lực tìm hiểu và phân tích nghiệp vụ', 'Năng xuất tạo IT,ST cao'], 'framework': [], 'tools': ['AWS', 'Git', 'Gitlab']}
#  98%|█████████▊| 1244/1274 [3:05:35<04:32,  9.09s/it]
# {'experience': 1, 'industries': ['An ninh mạng'], 'languages': ['shell', 'perl', 'python', 'c', 'c++'], 'soft-skill': ['Nghiên cứu', 'Ham học hỏi'], 'framework': [], 'tools': ['TCP/IP protocol', 'ipsec', 'SQL injection', 'transmission security', 'data packet structure', 'DDoS attack', 'WAF', 'Security Analyzel', 'Audit', 'Security Monitor', 'Windows', 'Linux', 'vmware esxi', 'vcenter', 'Firewall', 'Antivirus', 'Anti DDOS Appliance', 'WAF Appliance']}
#  98%|█████████▊| 1245/1274 [3:05:43<04:15,  8.83s/it]
# {'experience': 0, 'industries': ['IT', 'B2B', 'ERP', 'bán hàng'], 'languages': ['Tiếng Anh'], 'soft-skill': ['đàm phán', 'tiếp thị', 'năng động', 'định hướng mục tiêu', 'tạo và cung cấp các bài thuyết trình', 'đam mê', 'thích ứng', 'phát triển', 'ngoại hình sáng'], 'framework': [], 'tools': []}
#  98%|█████████▊| 1246/1274 [3:05:53<04:10,  8.94s/it]
# {'experience': 2, 'industries': ['Phát triển thương hiệu', 'Đối tác', 'CNTT', 'SaaS', 'Bán lẻ', 'Sản xuất'], 'languages': ['Tiếng Anh'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Tư duy logic', 'Sáng tạo nội dung', 'Tìm hiểu insight khách hàng'], 'framework': [], 'tools': ['Photoshop']}
#  98%|█████████▊| 1247/1274 [3:06:02<04:02,  8.97s/it]
# {'experience': 5, 'industries': ['lập trình ứng dụng web', 'lập trình AI'], 'languages': ['Java'], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'giao tiếp', 'trình bày', 'ước lượng nỗ lực', 'đàm phán', 'giải quyết xung đột'], 'framework': [], 'tools': ['Jira', 'AWS', 'Git', 'GitLab']}
#  98%|█████████▊| 1248/1274 [3:06:11<03:56,  9.11s/it]
# {'experience': 3, 'industries': ['kiểm thử phần mềm', 'Data', 'Banking', 'Payment', 'Mobile App', 'Web', 'API', 'Agile', 'Scrum'], 'languages': ['SQL'], 'soft-skill': ['chịu áp lực', 'thích ứng nhanh', 'giải quyết vấn đề'], 'framework': [], 'tools': ['AWS', 'ISTQB', 'kiểm thử tự động', 'kiểm thử hiệu năng']}
#  98%|█████████▊| 1249/1274 [3:06:20<03:47,  9.11s/it]
# {'experience': 2, 'industries': ['Quản lý dự án công nghệ thông tin'], 'languages': [], 'soft-skill': ['Làm việc độc lập', 'Làm việc theo nhóm', 'Giao tiếp', 'Trình bày', 'Làm việc dưới áp lực cao', 'Nhạy bén', 'Tiếp thu nhanh', 'Tư duy logic', 'Giao tiếp', 'Sáng tạo'], 'framework': ['Agile', 'Waterfall'], 'tools': []}
#  98%|█████████▊| 1250/1274 [3:06:30<03:46,  9.44s/it]
# {'experience': 1, 'industries': ['Công nghệ thông tin'], 'languages': ['Tiếng Anh', 'Tiếng Trung'], 'soft-skill': ['Cẩn thận', 'Có trách nhiệm', 'Chịu được áp lực công việc', 'Khả năng làm việc độc lập', 'Kĩ năng giao tiếp', 'Kĩ năng báo cáo'], 'framework': [], 'tools': ['Windows', 'mạng', 'phần cứng']}
#  98%|█████████▊| 1251/1274 [3:06:39<03:33,  9.30s/it]
# {'experience': 1, 'industries': ['lập trình Mobile App'], 'languages': ['Object C', 'Swift', 'Java', 'ReactNative', 'Flutter'], 'soft-skill': [], 'framework': [], 'tools': ['CI/CD', 'Jenkin', 'GIT', 'ANT']}
#  98%|█████████▊| 1252/1274 [3:06:48<03:21,  9.15s/it]
# {'experience': 3, 'industries': ['Phát triển ứng dụng', 'Phát triển dịch vụ', 'Phát triển hệ thống', 'Lập trình ứng dụng web', 'Phát triển ứng dụng đồng thời', 'Phát triển ứng dụng có hiệu suất cao', 'Lập trình hướng dịch vụ', 'Kiến trúc phân tán', 'Microservices', 'DevOps', 'Hệ thống đám mây', 'Dịch vụ điện toán đám mây'], 'languages': ['Golang', 'HTML', 'CSS', 'JavaScript', 'SQL'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Viết mã sạch', 'Giao tiếp', 'Làm việc nhóm', 'Phân tích', 'Làm việc độc lập'], 'framework': ['gin', 'echo', 'beego', 'gRPC', 'Kubernetes', 'Docker', 'ReactJS', 'VueJS', 'Svelte'], 'tools': ['Git', 'MySQL', 'XMPP', 'FreePBX', 'Keycloak']}
#  98%|█████████▊| 1253/1274 [3:06:58<03:19,  9.48s/it]
# {'experience': 1, 'industries': ['Lập trình game'], 'languages': ['C#', 'Unity'], 'soft-skill': ['Tư duy tốt', 'Chủ động', 'Trách nhiệm cao', 'Đam mê', 'Làm việc độc lập', 'Làm việc nhóm', 'Cởi mở', 'Học hỏi', 'Chia sẻ'], 'framework': [], 'tools': ['Google Play', 'AppStore']}
#  98%|█████████▊| 1254/1274 [3:07:08<03:06,  9.35s/it]
# {'experience': 1, 'industries': ['lập trình ứng dụng web'], 'languages': ['NodeJS'], 'soft-skill': [], 'framework': [], 'tools': ['Docker', 'PostgreSQL', 'MongoDB']}
#  99%|█████████▊| 1255/1274 [3:07:15<02:48,  8.86s/it]
# {'experience': 5, 'industries': ['Phân tích dữ liệu', 'AI', 'Khai thác dữ liệu', 'Lập trình ứng dụng web'], 'languages': ['SQL'], 'soft-skill': ['Suy luận logic', 'Tập trung vào chi tiết', 'Kỹ năng tổ chức tốt', 'Khả năng làm việc đa nhiệm', 'Chịu được áp lực cao'], 'framework': [], 'tools': ['Airflow', 'Git', 'Jupyter', 'H2O', 'Datahub', 'Jira', 'Visualize']}
#  99%|█████████▊| 1256/1274 [3:07:25<02:43,  9.08s/it]
# {'experience': 5, 'industries': ['E-logistics', 'E-commerce', 'ERP services', 'B2B solutions', 'artificial intelligence (AI)', 'Internet of Things (IoT)'], 'languages': [], 'soft-skill': ['Communication', 'problem-solving', 'analytical', 'project management', 'multitasking', 'withstand high pressure'], 'framework': ['ERP', 'Odoo', 'Shopify'], 'tools': []}
#  99%|█████████▊| 1257/1274 [3:07:33<02:27,  8.70s/it]
# {'experience': 1, 'industries': ['Lập trình ứng dụng web'], 'languages': ['Java', 'SQL', 'NoSQL'], 'soft-skill': ['Đam mê', 'Có trách nhiệm cao trong công việc', 'Có khả năng làm việc độc lập', 'Làm việc nhóm'], 'framework': ['Spring MVC', 'Spring Boots', 'Hibernate', 'AngularJS', 'ReactJS'], 'tools': ['Git', 'SVN', 'Eclipse', 'IntelliJ', 'NetBeans', 'API (Restful, SOAP)', 'SCM']}
#  99%|█████████▊| 1258/1274 [3:07:43<02:25,  9.08s/it]
# {'experience': 1, 'industries': ['lập trình Fullstack', 'tài chính ngân hàng'], 'languages': ['Java'], 'soft-skill': [], 'framework': ['Angularjs', 'ReactJS'], 'tools': ['Oracle', 'SQLserver', 'PostgreSQL', 'Mongodb', 'restful', 'GraqpQL']}
#  99%|█████████▉| 1259/1274 [3:07:50<02:10,  8.71s/it]
# {'experience': 3, 'industries': ['Công nghệ thông tin', 'Phát triển ứng dụng web', 'Microservice', 'CICD', 'Containerization', 'Xử lý bất đồng bộ', 'Xử lý đa nhiệm', 'Event sourcing', 'Hệ thống Message Queue'], 'languages': ['Go'], 'soft-skill': ['Kỹ năng mã hóa', 'Hiệu đính', 'Đạo đức nghề nghiệp tốt'], 'framework': [], 'tools': ['MySQL', 'MongoDB', 'Cassandra', 'Docker', 'Kubernetes', 'Kafka', 'RabbitMQ', 'Git']}
#  99%|█████████▉| 1260/1274 [3:08:00<02:03,  8.83s/it]
# {'experience': 0, 'industries': ['Phân tích dữ liệu'], 'languages': ['Python', 'R', 'SQL'], 'soft-skill': ['Giao tiếp', 'Làm việc nhóm', 'Trách nhiệm', 'Học hỏi nhanh chóng'], 'framework': [], 'tools': ['Pandas', 'NumPy', 'Scikit-learn', 'Matplotlib']}
#  99%|█████████▉| 1261/1274 [3:08:09<01:56,  8.94s/it]
# {'experience': 2, 'industries': ['Lập trình web'], 'languages': ['PHP', 'HTML', 'CSS'], 'soft-skill': ['Cẩn thận', 'Kiên nhẫn', 'Đam mê lập trình', 'Sẵn sàng học hỏi', 'Chịu được áp lực công việc', 'Phân tích', 'Giải quyết vấn đề', 'Làm việc độc lập', 'Làm việc theo nhóm'], 'framework': ['CakePHP', 'Yii', 'CodeIgniter', 'Laravel', 'Fuel'], 'tools': ['SVN', 'GIT', 'MySQL', 'Maria DB', 'MongoDB']}
#  99%|█████████▉| 1262/1274 [3:08:18<01:47,  8.95s/it]
# {'experience': 4, 'industries': ['Lập trình ứng dụng web'], 'languages': ['C#', '.NET'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Giao tiếp tiếng Anh'], 'framework': [], 'tools': ['Azure', 'Git']}
#  99%|█████████▉| 1263/1274 [3:08:27<01:38,  8.92s/it]
# {'experience': 1, 'industries': ['lập trình ứng dụng web', 'an toàn thông tin'], 'languages': ['Python'], 'soft-skill': ['thích ứng nhanh', 'giải quyết vấn đề', 'làm việc nhóm', 'giao tiếp', 'trách nhiệm', 'vui vẻ', 'tự động hóa', 'đổi mới', 'chấp nhận thử thách'], 'framework': [], 'tools': ['Frida', 'Xposed', 'Fiddler', 'Clarles', 'jadx', 'IDA', 'JEB', 'Inline Hook']}
#  99%|█████████▉| 1264/1274 [3:08:36<01:30,  9.08s/it]
# {'experience': 5, 'industries': ['Lập trình Backend', 'Thiết kế kiến trúc sản phẩm trên Cloud', 'Thiết kế kiến trúc sản phẩm trên Onpremise Server', 'Thiết kế, xây dựng và triển khai hệ thống Microservice', 'Cơ sở dữ liệu (SQL/NoSQL)', 'Phát triển phần mềm'], 'languages': ['Golang'], 'soft-skill': ['Thích ứng nhanh', 'Giải quyết vấn đề', 'Phân tích ứng dụng công nghệ trong các bài toán cụ thể'], 'framework': '', 'tools': ['Docker', 'Kubernetes', 'Amazone', 'Azure']}
#  99%|█████████▉| 1265/1274 [3:08:45<01:21,  9.07s/it]
# {'experience': 2, 'industries': ['Lập trình ứng dụng web', 'Fintech'], 'languages': ['Java'], 'soft-skill': ['Nhiệt tình', 'Ham học hỏi', 'Làm việc độc lập', 'Làm việc nhóm', 'Chủ động', 'Cẩn thận', 'Kiên nhẫn', 'Đam mê lập trình', 'Sẵn sàng học hỏi'], 'framework': ['Spring JPA', 'Spring Boot', 'Spring Cloud'], 'tools': ['MySQL', 'Postgres', 'JSON', 'Rest API']}
#  99%|█████████▉| 1266/1274 [3:08:54<01:12,  9.02s/it]
# {'experience': 3, 'industries': ['Lập trình Backend'], 'languages': ['Java', 'SQL', 'PL/SQL'], 'soft-skill': ['Tư duy về thiết kế hướng đối tượng', 'nắm vững kiến thức về cấu trúc dữ liệu và giải thuật', 'lập trình hướng đối tượng'], 'framework': ['EE', 'Spring', 'Struts', 'Hibernate'], 'tools': ['Oracle', 'MySQL', 'NoSQL']}
#  99%|█████████▉| 1267/1274 [3:09:04<01:04,  9.21s/it]
# {'experience': 1, 'industries': ['Xử lý ngôn ngữ tự nhiên', 'Phát triển bản đồ', 'GIS', 'Machine learning', 'Học sâu', 'Lập trình web backend'], 'languages': [], 'soft-skill': ['Tư duy logic', 'Học hỏi', 'Giải quyết vấn đề', 'Quản lý công việc', 'Quản lý thời gian', 'Giao tiếp'], 'framework': [], 'tools': ['Tensorflow', 'Pytorch', 'Mxnet', 'MySQL', 'PostgreSQL', 'ElasticSearch']}
# 100%|█████████▉| 1268/1274 [3:09:13<00:54,  9.13s/it]
# {'experience': 3, 'industries': ['Phân tích nghiệp vụ'], 'languages': [], 'soft-skill': ['Giao tiếp', 'Làm việc nhóm', 'Phân tích', 'Giải quyết vấn đề', 'Làm việc độc lập', 'Quản lý thời gian', 'Nhiệt tình', 'Có trách nhiệm', 'Ham học hỏi', 'Tự giác', 'Chú trọng đến mục đích cuối cùng'], 'framework': [], 'tools': ['Vẽ mockup', 'Prototype']}
# 100%|█████████▉| 1269/1274 [3:09:22<00:46,  9.31s/it]
# {'experience': 1, 'industries': ['xử lý dữ liệu lớn', 'khoa học dữ liệu', 'blockchain', 'xây dựng pipeline dữ liệu', 'lập trình ứng dụng web'], 'languages': ['Scala', 'SQL', 'Python'], 'soft-skill': ['tư duy thiết kế cơ sở dữ liệu', 'tối ưu hóa truy vấn'], 'framework': '', 'tools': ['Hadoop', 'Spark', 'DBT', 'Airflow', 'AWS', 'EMR', 'Glue', 'S3', 'EC2']}
# 100%|█████████▉| 1270/1274 [3:09:32<00:37,  9.28s/it]
# {'experience': 0, 'industries': ['Lập trình ứng dụng web', 'Phân tích dữ liệu'], 'languages': ['SQL', 'Excel'], 'soft-skill': ['Giải quyết vấn đề', 'Phân tích', 'Giao tiếp', 'Làm việc độc lập', 'Lập kế hoạch', 'Tư duy phản biện', 'Làm việc nhóm', 'Làm việc hiệu quả dưới áp lực'], 'framework': [], 'tools': ['Power BI']}
# 100%|█████████▉| 1271/1274 [3:09:41<00:27,  9.25s/it]
# {'experience': 3, 'industries': ['Lập trình Game'], 'languages': [], 'soft-skill': ['Nghiên cứu', 'Nâng cao kiến thức chuyên môn', 'Truyền lửa', 'Chia sẻ', 'Trình bày ý tưởng rõ ràng', 'Rành mạch', 'Tự tin', 'Lắng nghe', 'Kiên trì', 'Chịu trách nhiệm', 'Đúng giờ'], 'framework': ['Unity'], 'tools': ['Game Engine', 'Networking Enginer', 'Game AI']}
# 100%|█████████▉| 1272/1274 [3:09:51<00:18,  9.49s/it]
# {'experience': 2, 'industries': ['Lập trình ứng dụng web', 'Quản lý dự án'], 'languages': [], 'soft-skill': ['Giải quyết vấn đề', 'Lãnh đạo', 'Làm việc nhóm'], 'framework': [], 'tools': []}
# 100%|█████████▉| 1273/1274 [3:10:00<00:09,  9.33s/it]
# {'experience': 0, 'industries': ['Thông tin di động', 'Mạng viễn thông'], 'languages': [], 'soft-skill': ['Nghiên cứu', 'Sáng tạo', 'Làm việc độc lập', 'Tự quản lý', 'Sắp xếp công việc', 'Trách nhiệm', 'Trung thực', 'Ham học hỏi', 'Giao tiếp tiếng Anh'], 'framework': [], 'tools': ['Tin học văn phòng']}
# 100%|██████████| 1274/1274 [3:10:09<00:00,  8.96s/it]

# %%
bk_experience = experience.copy()
bk_industries= industries.copy()
bk_languages = languages.copy()
bk_framework = framework.copy()
bk_soft_skill = soft_skill.copy()
bk_tools = tools.copy()

# %%
df = df.assign(experience=experience, industries=industries, languages=languages, framework=framework, soft_skill=soft_skill, tools=tools)
df.to_csv('/content/drive/MyDrive/IT_Job_Posting_final.csv')
